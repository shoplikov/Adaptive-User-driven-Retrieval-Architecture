# %%
! git clone https://github.com/ggml-org/llama.cpp
# Out:
# Cloning into 'llama.cpp'...
# remote: Enumerating objects: 62313, done.
# remote: Counting objects: 100% (405/405), done.
# remote: Compressing objects: 100% (327/327), done.
# remote: Total 62313 (delta 192), reused 78 (delta 78), pack-reused 61908 (from 4)
# Receiving objects: 100% (62313/62313), 155.50 MiB | 38.93 MiB/s, done.
# Resolving deltas: 100% (45098/45098), done.

# %%
import boto3
import os

# %%
s3 = boto3.client("s3")
bucket = "aura-llm-models"# conversations.json
s3.download_file(bucket, "conversations/conversations_raw.json", "conversations_raw.json")
